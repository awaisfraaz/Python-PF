# %%
import math

math.sqrt(16)
math.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt,pi
print(pi)
# Out:
# 3.141592653589793

# %%
from math import *

# %%
from package.maths import add
# Out:
#   Cell In[15], line 1
#     from package.maths import add(1,2)
#                                  ^
# SyntaxError: invalid syntax

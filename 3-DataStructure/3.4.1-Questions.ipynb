# %%
number_dict={x: x**2 for x in range(11)}
print(number_dict)

# %%
print("The square of 5 is:", number_dict[5])
# Out:
# The square of 5 is: 25

# %%
# Adding a new key-value pair
number_dict[11] = 121

del number_dict[1]  # Removing the key-value pair for 3
print("Updated dictionary:", number_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 4
#       1 # Adding a new key-value pair
#       2 number_dict[11] = 121
# ----> 4 del number_dict[1]  # Removing the key-value pair for 3
#       5 print("Updated dictionary:", number_dict)
#
# KeyError: 1

# %%
dict1={x: x**2 for x in range(5)}
print(dict1)

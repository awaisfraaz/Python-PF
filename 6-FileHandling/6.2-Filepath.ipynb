# %%
import os
os.getcwd()
# Out:
# 'd:\\OneDrive\\Desktop\\DataScience\\Python-PF\\6-FileHandling'

# %%
#creating a directory
os.mkdir('package')

# %%
#list all the files and directories in the current directory
items = os.listdir('.')
print(items)
# Out:
# ['6.1-Fileoperation.ipynb', '6.2-Filepath.ipynb', 'data.txt', 'data1.txt', 'output.bin', 'output.txt', 'package']

# %%
path = 'data1.txt'
if os.path.exists(path):
     print(f'this path {path} exists')
else:
     open with
# Out:
# this path data1.txt exists

# %%
path = 'data1.txt'
if os.path.isfile(path):
     print(f'this path {path} exists')
elif os.path.isdir()

# %%
add = lambda a,b: a+b
type(add)
add(2,3)

subtract = lambda a,b: a-b
subtract(5,2)

multiply = lambda a,b: a*b
multiply(3,4)

divide = lambda a,b: a/b
divide(10,2)
# Out:
# 5.0

# %%
even = lambda x: x % 2 == 0
even(4)
# Out:
# True

# %%
odd = lambda x: x % 2 != 0
odd(5)
# Out:
# True

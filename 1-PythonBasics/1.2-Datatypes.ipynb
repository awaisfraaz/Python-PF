# %%
age=12
name="John"
gpa=3.5
is_true=True

# %%
a=12
b=12
type(a==b)
# Out:
# bool

# %%
Name="NY"+212
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Name="NY"+212
#
# TypeError: can only concatenate str (not "int") to str

# %%
Name="NY"+str(212)
print(Name)
#type casting
# Out:
# NY212

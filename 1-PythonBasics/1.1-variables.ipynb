# %%
name="awais"
age=20
gpa=3.5
is_student=True
print("Name:", name)
print("Age:", age)
print("GPA:", gpa)
print("Is Student:", is_student)
# Out:
# Name: awais
# Age: 20
# GPA: 3.5
# Is Student: True

# %%
#Variables Names descriptive 
first_name = "Awais"
last_name = "fraaz"

# %%
#case senstivity 
Name="awais"
name="fraaz"

Name==name
# Out:
# False

# %%
#Type converstion 
print(type(age))
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 20
# <class 'str'>

# %%
#cannot string to int
name_int=int(name)

#similarly for float and int
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 #cannot string to int
# ----> 2 name_int=int(name)
#
# ValueError: invalid literal for int() with base 10: 'fraaz'

# %%
#Dynamic Typing 

variable=20
print(variable,type(variable))
variable="awais"
print(variable,type(variable))
# Out:
# 20 <class 'int'>
# awais <class 'str'>

# %%
#by defult input function get string 
age1=int(input("Enter the age :"))
print(age1,type(age1))
# Out:
# 23 <class 'int'>

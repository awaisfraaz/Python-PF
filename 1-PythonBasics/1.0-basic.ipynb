# %%
# Case Senstivity 
Name="Awais"
name="Fraaz"

print(Name)
print(name)
# Out:
# Awais
# Fraaz

# %%
#Identation 
age=20
if age > 18:
    print("You are an adult")
print("outside the if block")
# Out:
# You are an adult
# outside the if block

# %%
#line continuation 
z=3+\
    4+\
    5
print(z)
# Out:
# 12

# %%
name="Awais"
print(type(name))
# Out:
# <class 'str'>

# %%
age=20
print(type(age))
# Out:
# <class 'int'>

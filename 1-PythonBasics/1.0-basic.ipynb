# %%
# Case Senstivity 
Name="Awais"
name="Fraaz"

print(Name)
print(name)
# Out:
# Awais
# Fraaz

# %%
#Identation 
age=20
if age > 18:
    print("You are an adult")
print("outside the if block")
# Out:
# You are an adult
# outside the if block

# %%
print("Helllo, World!")
# Out:
# Helllo, World!

# %%
## case Sensitvity##
name="Awais"
Name="Fraaz"

print(name)
print(Name)
# Out:
# Awais
# Fraaz

# %%
# Idnetation 
age = 20
if age > 18:
    print(age)
    print("You are an adult")
print("This is outside the if block")
print(age)
# Out:
# 20
# You are an adult
# This is outside the if block
# 20

# %%
#Arithmetic operation 
a=10
b=20
#Addition
c=a+b
#Subtraction
d=a-b
#Multiplication
e=a*b
#Division
f=a/b
#floor Division
g=a//b
#Modulus
h=a%b
#Exponentiation
i=a**b
print(c,d,e,f,g,h,i)
# Out:
# 30 -10 200 0.5 0 10 100000000000000000000

# %%
#comparison operator 
str1="Awias"
str2="Awias"
str1==str2
# Out:
# True

# %%
str2="Awias1"
str1==str2
# Out:
# False

# %%
a=10
b=20
a>b
# Out:
# False

# %%
a=20
a>=b
# Out:
# True

# %%
#logical operator
a=True
b=False
a or b
a and b
# Out:
# False

# %%
not a
# Out:
# False

# %%
class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype
    def showdata(self):
        print("Windows:", self.windows)
        print("Doors:", self.doors)
        print("Engine Type:", self.enginetype)  
    def drive(self):
        print("The per")

# %%
#Inheritance
class Tesla(Car):
    
    def __init__(self,windows,doors,enginetype,is_autopilot):
        super().__init__(windows,doors,enginetype)
        self.autopilot = autopilot
    def selfdriving(self):
        
        print(f"Tesla supports self driveing{self.is_autopilot}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #Inheritance
# ----> 2 class Tesla(Car):
#       4     def __init__(self,windows,doors,enginetype,is_autopilot):
#       5         super().__init__(windows,doors,enginetype)
#
# NameError: name 'Car' is not defined
